# %%
import numpy as np
import pandas as pd

# %%
import pickle
matches = pickle.load(open('dataset_1.pkl' , 'rb'))

# %%
matches
# Out:
#                                                 innings  info.city  \
# 0     [{'1st innings': {'team': 'Australia', 'delive...   Brisbane
# 1     [{'1st innings': {'team': 'Australia', 'delive...        NaN
# 2     [{'1st innings': {'team': 'Pakistan', 'deliver...      Perth
# 3     [{'1st innings': {'team': 'Australia', 'delive...        NaN
# 4     [{'1st innings': {'team': 'Australia', 'delive...        NaN
# ...                                                 ...        ...
# 2028  [{'1st innings': {'team': 'Afghanistan', 'deli...    Belfast
# 2029  [{'1st innings': {'team': 'Afghanistan', 'deli...    Belfast
# 2030  [{'1st innings': {'team': 'Ireland', 'deliveri...    Belfast
# 2031  [{'1st innings': {'team': 'Scotland', 'deliver...  Edinburgh
# 2032  [{'1st innings': {'team': 'United Arab Emirate...  Edinburgh
#
#         info.dates info.gender info.match_type info.outcome.winner  \
# 0     [2017-01-13]        male             ODI           Australia
# ...

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1799 entries, 0 to 2032
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   innings               1799 non-null   object
#  1   info.city             1488 non-null   object
#  2   info.dates            1799 non-null   object
#  3   info.gender           1799 non-null   object
#  4   info.match_type       1799 non-null   object
#  5   info.outcome.winner   1708 non-null   object
#  6   info.overs            1799 non-null   int64
#  7   info.player_of_match  1681 non-null   object
#  8   info.teams            1799 non-null   object
#  9   info.toss.decision    1799 non-null   object
#  10  info.toss.winner      1799 non-null   object
#  11  info.umpires          1799 non-null   object
#  12  info.venue            1799 non-null   object
#  13  match_id              1799 non-null   int32
# dtypes: int32(1), int64(1), object(12)
# ...

# %%
count = 1
delivery_df1 = pd.DataFrame()
for index, row in matches.iterrows():
    count+=1
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'batsman':batsman,
            'bowler':bowler,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    delivery_df1 = pd.concat([delivery_df1, loop_df], ignore_index=True)

# %%
delivery_df1
# Out:
#         match_id                             teams          batting_team  \
# 0              2             [Australia, Pakistan]             Australia
# 1              2             [Australia, Pakistan]             Australia
# 2              2             [Australia, Pakistan]             Australia
# 3              2             [Australia, Pakistan]             Australia
# 4              2             [Australia, Pakistan]             Australia
# ...          ...                               ...                   ...
# 519641      1800  [Scotland, United Arab Emirates]  United Arab Emirates
# 519642      1800  [Scotland, United Arab Emirates]  United Arab Emirates
# 519643      1800  [Scotland, United Arab Emirates]  United Arab Emirates
# 519644      1800  [Scotland, United Arab Emirates]  United Arab Emirates
# 519645      1800  [Scotland, United Arab Emirates]  United Arab Emirates
#
#         ball       batsman         bowler  runs player_dismissed       city  \
# ...

# %%
def bowl(row):
    for team in row["teams"]:
        if team != row["batting_team"]:
            return team

# %%
delivery_df1["bowling_team"] = delivery_df1.apply(bowl , axis=1)

# %%
delivery_df1
# Out:
#         match_id                             teams          batting_team  \
# 0              2             [Australia, Pakistan]             Australia
# 1              2             [Australia, Pakistan]             Australia
# 2              2             [Australia, Pakistan]             Australia
# 3              2             [Australia, Pakistan]             Australia
# 4              2             [Australia, Pakistan]             Australia
# ...          ...                               ...                   ...
# 519641      1800  [Scotland, United Arab Emirates]  United Arab Emirates
# 519642      1800  [Scotland, United Arab Emirates]  United Arab Emirates
# 519643      1800  [Scotland, United Arab Emirates]  United Arab Emirates
# 519644      1800  [Scotland, United Arab Emirates]  United Arab Emirates
# 519645      1800  [Scotland, United Arab Emirates]  United Arab Emirates
#
#         ball       batsman         bowler  runs player_dismissed       city  \
# ...

# %%
delivery_df1.drop("teams" , axis =1 , inplace =True)

# %%
delivery_df1["batting_team"].unique()
# Out:
# array(['Australia', 'Pakistan', 'Afghanistan', 'Scotland', 'Zimbabwe',
#        'New Zealand', 'Bangladesh', 'South Africa', 'India', 'England',
#        'Sri Lanka', 'Hong Kong', 'Papua New Guinea', 'West Indies',
#        'Ireland', 'United Arab Emirates', 'Nepal',
#        'United States of America', 'Namibia', 'Oman', 'Africa XI',
#        'Kenya', 'Bermuda', 'Netherlands', 'Canada', 'Asia XI'],
#       dtype=object)

# %%
teams = ["Australia",
        "Pakistan",
        "Afghanisthan",
        "New Zealand",
        "Bangladesh",
        "South Africa",
        "India",
        "England",
        "Sri Lanka",
        "Netherlands"]

# %%
delivery_df1 = delivery_df1[delivery_df1["batting_team"].isin(teams)]
delivery_df1 = delivery_df1[delivery_df1["bowling_team"].isin(teams)]

# %%
delivery_df1
# Out:
#         match_id batting_team  ball       batsman         bowler  runs  \
# 0              2    Australia   0.1     DA Warner  Mohammad Amir     0
# 1              2    Australia   0.2     DA Warner  Mohammad Amir     0
# 2              2    Australia   0.3     DA Warner  Mohammad Amir     0
# 3              2    Australia   0.4     DA Warner  Mohammad Amir     0
# 4              2    Australia   0.5     DA Warner  Mohammad Amir     1
# ...          ...          ...   ...           ...            ...   ...
# 518126      1795    Sri Lanka  39.5  SS Pathirana       MA Starc     0
# 518127      1795    Sri Lanka  39.6  SS Pathirana       MA Starc     0
# 518128      1795    Sri Lanka  39.7  SS Pathirana       MA Starc     1
# 518129      1795    Sri Lanka  40.1  SS Pathirana      SM Boland     0
# 518130      1795    Sri Lanka  40.2  SS Pathirana      SM Boland     0
#
#        player_dismissed      city                                    venue  \
# ...

# %%
output = delivery_df1[["match_id" , "batting_team" , "bowling_team" , "ball" , "runs" , "player_dismissed" , "city", "venue"]]

# %%
output
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia     Pakistan   0.1     0                0
# 1              2    Australia     Pakistan   0.2     0                0
# 2              2    Australia     Pakistan   0.3     0                0
# 3              2    Australia     Pakistan   0.4     0                0
# 4              2    Australia     Pakistan   0.5     1                0
# ...          ...          ...          ...   ...   ...              ...
# 518126      1795    Sri Lanka    Australia  39.5     0                0
# 518127      1795    Sri Lanka    Australia  39.6     0                0
# 518128      1795    Sri Lanka    Australia  39.7     1                0
# 518129      1795    Sri Lanka    Australia  40.1     0                0
# 518130      1795    Sri Lanka    Australia  40.2     0     SS Pathirana
#
#             city                                    venue
# ...

# %%
pickle.dump(output , open("dataset_2.pkl" , "wb"))
